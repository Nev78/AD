# %% [markdown]
# # Лабараторна робота №4
# # Структури для роботи з великими обсягами даних в Python
# ## Невмержицька Дар'я ФБ-23
# ### Мета роботи: Мета: отримати навички роботи із структурами для зберігання в Python(python, numpy, pandas, numpy array, dataframe, timeit)
# ### Хід роботи:
# ## dataframe
# #### Завдання першого рівня

# %%
#Імпортуємо бібліотеки
import pandas as pd
import numpy as np

# %%
# Вказуємо назви колонок і їх типи даних
column_names = ['Date', 'Time', 'Global_active_power', 'Global_reactive_power', 'Voltage', 'Global_intensity', 'Sub_metering_1', 'Sub_metering_2', 'Sub_metering_3']
data_types = {'Date': 'str', 'Time': 'str', 'Global_active_power': 'float', 'Global_reactive_power': 'float', 'Voltage': 'float', 'Global_intensity': 'float', 'Sub_metering_1': 'float', 'Sub_metering_2': 'float', 'Sub_metering_3': 'float'}

# Читаємо набір даних, вказуючи назви колонок і типи даних
df = pd.read_table("household_power_consumption.txt", sep=";", header=0, names=column_names, dtype=data_types, na_values='?')

# %%
#Перетворюємо колонку Date в формат дати і змінюємо формат
df['Date'] = pd.to_datetime(df['Date'], format = "%d/%m/%Y").dt.strftime("%Y-%m-%d")
df
# Out:
#                Date      Time  Global_active_power  Global_reactive_power  \
# 0        2006-12-16  17:24:00                4.216                  0.418
# 1        2006-12-16  17:25:00                5.360                  0.436
# 2        2006-12-16  17:26:00                5.374                  0.498
# 3        2006-12-16  17:27:00                5.388                  0.502
# 4        2006-12-16  17:28:00                3.666                  0.528
# ...             ...       ...                  ...                    ...
# 2075254  2010-11-26  20:58:00                0.946                  0.000
# 2075255  2010-11-26  20:59:00                0.944                  0.000
# 2075256  2010-11-26  21:00:00                0.938                  0.000
# 2075257  2010-11-26  21:01:00                0.934                  0.000
# 2075258  2010-11-26  21:02:00                0.932                  0.000
#
#          Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# ...

# %% [markdown]
# #### Drop Non-available Data

# %%
#Виводимо всі рядки, які містять NaN значення в будь-якій колонці
df[df.isna().any(axis=1)]
# Out:
#                Date      Time  Global_active_power  Global_reactive_power  \
# 6839     2006-12-21  11:23:00                  NaN                    NaN
# 6840     2006-12-21  11:24:00                  NaN                    NaN
# 19724    2006-12-30  10:08:00                  NaN                    NaN
# 19725    2006-12-30  10:09:00                  NaN                    NaN
# 41832    2007-01-14  18:36:00                  NaN                    NaN
# ...             ...       ...                  ...                    ...
# 1990185  2010-09-28  19:09:00                  NaN                    NaN
# 1990186  2010-09-28  19:10:00                  NaN                    NaN
# 1990187  2010-09-28  19:11:00                  NaN                    NaN
# 1990188  2010-09-28  19:12:00                  NaN                    NaN
# 2027411  2010-10-24  15:35:00                  NaN                    NaN
#
#          Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# ...

# %%
#Видаляємо всі рядки з NaN значеннями і оновлюємо індекси
df=df.dropna().reset_index(drop=True)
df
# Out:
#                Date      Time  Global_active_power  Global_reactive_power  \
# 0        2006-12-16  17:24:00                4.216                  0.418
# 1        2006-12-16  17:25:00                5.360                  0.436
# 2        2006-12-16  17:26:00                5.374                  0.498
# 3        2006-12-16  17:27:00                5.388                  0.502
# 4        2006-12-16  17:28:00                3.666                  0.528
# ...             ...       ...                  ...                    ...
# 2049275  2010-11-26  20:58:00                0.946                  0.000
# 2049276  2010-11-26  20:59:00                0.944                  0.000
# 2049277  2010-11-26  21:00:00                0.938                  0.000
# 2049278  2010-11-26  21:01:00                0.934                  0.000
# 2049279  2010-11-26  21:02:00                0.932                  0.000
#
#          Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# ...

# %% [markdown]
# #### Task 1: Обрати всі домогосподарства, у яких загальна активна споживана потужність перевищує 5 кВт.

# %%
df_1=df[df["Global_active_power"]>5]
df_1
# Out:
#                Date      Time  Global_active_power  Global_reactive_power  \
# 1        2006-12-16  17:25:00                5.360                  0.436
# 2        2006-12-16  17:26:00                5.374                  0.498
# 3        2006-12-16  17:27:00                5.388                  0.502
# 11       2006-12-16  17:35:00                5.412                  0.470
# 12       2006-12-16  17:36:00                5.224                  0.478
# ...             ...       ...                  ...                    ...
# 2043377  2010-11-22  18:40:00                5.408                  0.150
# 2043378  2010-11-22  18:41:00                5.528                  0.144
# 2045607  2010-11-24  07:50:00                5.172                  0.050
# 2045608  2010-11-24  07:51:00                5.750                  0.000
# 2047018  2010-11-25  07:21:00                5.074                  0.240
#
#          Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# ...

# %% [markdown]
# #### Task 2: Обрати всі домогосподарства, у яких вольтаж перевищую 235 В.

# %%
df_2=df[df["Voltage"]>235]
df_2
# Out:
#                Date      Time  Global_active_power  Global_reactive_power  \
# 4        2006-12-16  17:28:00                3.666                  0.528
# 5        2006-12-16  17:29:00                3.520                  0.522
# 6        2006-12-16  17:30:00                3.702                  0.520
# 7        2006-12-16  17:31:00                3.700                  0.520
# 14       2006-12-16  17:38:00                4.054                  0.422
# ...             ...       ...                  ...                    ...
# 2049275  2010-11-26  20:58:00                0.946                  0.000
# 2049276  2010-11-26  20:59:00                0.944                  0.000
# 2049277  2010-11-26  21:00:00                0.938                  0.000
# 2049278  2010-11-26  21:01:00                0.934                  0.000
# 2049279  2010-11-26  21:02:00                0.932                  0.000
#
#          Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# ...

# %% [markdown]
# #### Task 3: Обрати всі домогосподарства, у яких сила струму лежить в межах 19-20 А, для них виявити ті, у яких пральна машина та холодильних споживають більше, ніж бойлер та кондиціонер.

# %%
df_3_1=df[(df["Global_intensity"]>=19) & (df["Global_intensity"]<=20)]
df_3_1
# Out:
#                Date      Time  Global_active_power  Global_reactive_power  \
# 10       2006-12-16  17:34:00                4.448                  0.498
# 24       2006-12-16  17:48:00                4.474                  0.000
# 33       2006-12-16  17:57:00                4.512                  0.000
# 45       2006-12-16  18:09:00                4.464                  0.136
# 52       2006-12-16  18:16:00                4.524                  0.076
# ...             ...       ...                  ...                    ...
# 2045610  2010-11-24  07:53:00                4.666                  0.000
# 2045611  2010-11-24  07:54:00                4.694                  0.000
# 2045612  2010-11-24  07:55:00                4.602                  0.000
# 2045613  2010-11-24  07:56:00                4.536                  0.000
# 2045614  2010-11-24  07:57:00                4.626                  0.000
#
#          Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# ...

# %%
df_3_2=df_3_1[df_3_1["Sub_metering_2"]>df_3_1["Sub_metering_3"]]
df_3_2
# Out:
#                Date      Time  Global_active_power  Global_reactive_power  \
# 45       2006-12-16  18:09:00                4.464                  0.136
# 460      2006-12-17  01:04:00                4.582                  0.258
# 464      2006-12-17  01:08:00                4.618                  0.104
# 475      2006-12-17  01:19:00                4.636                  0.140
# 476      2006-12-17  01:20:00                4.634                  0.152
# ...             ...       ...                  ...                    ...
# 2045610  2010-11-24  07:53:00                4.666                  0.000
# 2045611  2010-11-24  07:54:00                4.694                  0.000
# 2045612  2010-11-24  07:55:00                4.602                  0.000
# 2045613  2010-11-24  07:56:00                4.536                  0.000
# 2045614  2010-11-24  07:57:00                4.626                  0.000
#
#          Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# ...

# %% [markdown]
# #### Task 4: Обрати випадковим чином 500000 домогосподарств (без повторів елементів вибірки), для них обчислити середні величини усіх 3-х груп споживання електричної енергії, а також

# %%
random_indicies=np.random.choice(len(df), 500000, replace=False)

# %%
df_4 = df.loc[random_indicies]
df_4
# Out:
#               Date      Time  Global_active_power  Global_reactive_power  \
# 542970  2007-12-31  12:29:00                4.350                  0.444
# 730158  2008-05-09  12:22:00                2.876                  0.252
# 777953  2008-06-11  16:59:00                0.210                  0.000
# 171908  2007-04-15  02:41:00                0.290                  0.106
# 83616   2007-02-12  19:06:00                1.526                  0.078
# ...            ...       ...                  ...                    ...
# 143704  2007-03-26  12:37:00                0.578                  0.242
# 883121  2008-08-23  17:51:00                0.162                  0.144
# 259357  2007-06-17  10:53:00                1.400                  0.198
# 435144  2007-10-17  15:18:00                0.356                  0.070
# 543315  2007-12-31  18:14:00                3.270                  0.084
#
#         Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# ...

# %%
# df_4 = df.drop_duplicates().sample(500000)
# df_4

# %%
df_4[['Sub_metering_1', 'Sub_metering_2', 'Sub_metering_3']].mean()
# Out:
# Sub_metering_1    1.107224
# Sub_metering_2    1.294784
# Sub_metering_3    6.468384
# dtype: float64

# %% [markdown]
# ![](.individual_household.ipynb.upload/paste-0.222638498989143)

# %% [markdown]
# #### Task 5: Обрати ті домогосподарства, які після 18-00 споживають понад 6 кВт за хвилину в середньому, серед відібраних визначити ті, у яких основне споживання електроенергії у вказаний проміжок часу припадає на пральну машину, сушарку, холодильник та освітлення (група 2 є найбільшою), а потім обрати кожен третій результат із першої половини та кожен четвертий результат із другої половини.

# %%
df_5_1=df[(df["Time"]>="18:00:00") & (df["Global_active_power"]>6)]

# %%
df_5_2 = df_5_1[
    (df_5_1["Sub_metering_2"] > df_5_1["Sub_metering_1"]) & 
    (df_5_1["Sub_metering_2"] > df_5_1["Sub_metering_3"])
].reset_index(drop=True)
df_5_2
# Out:
#             Date      Time  Global_active_power  Global_reactive_power  \
# 0     2006-12-16  18:05:00                6.052                  0.192
# 1     2006-12-16  18:06:00                6.752                  0.186
# 2     2006-12-16  18:07:00                6.474                  0.144
# 3     2006-12-16  18:08:00                6.308                  0.116
# 4     2006-12-16  18:35:00                6.072                  0.000
# ...          ...       ...                  ...                    ...
# 1056  2010-11-20  18:44:00                6.374                  0.392
# 1057  2010-11-20  18:45:00                6.564                  0.430
# 1058  2010-11-20  18:46:00                6.438                  0.308
# 1059  2010-11-20  18:49:00                6.210                  0.174
# 1060  2010-11-20  18:52:00                6.364                  0.126
#
#       Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# ...

# %%
half_index = len(df_5_2) // 2

df_5_2_first_half = df_5_2.loc[:half_index]
df_5_2_first_half_every_third = df_5_2_first_half.iloc[::3]

df_5_2_second_half = df_5_2.loc[half_index+1:]
df_5_2_second_half_every_fourth = df_5_2_second_half.iloc[::4]

# %%
df_5_2_first_half_every_third
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_5_2_first_half_every_third
#
# NameError: name 'df_5_2_first_half_every_third' is not defined

# %%
df_5_2_second_half_every_fourth

# %%
pd.concat([df_5_2_first_half_every_third, df_5_2_second_half_every_fourth])
# Out:
#             Date      Time  Global_active_power  Global_reactive_power  \
# 0     2006-12-16  18:05:00                6.052                  0.192
# 3     2006-12-16  18:08:00                6.308                  0.116
# 6     2006-12-28  20:58:00                6.386                  0.374
# 9     2006-12-28  21:02:00                8.088                  0.262
# 12    2006-12-28  21:05:00                7.230                  0.152
# ...          ...       ...                  ...                    ...
# 1043  2010-11-20  18:31:00                6.830                  0.394
# 1047  2010-11-20  18:35:00                6.784                  0.364
# 1051  2010-11-20  18:39:00                6.362                  0.372
# 1055  2010-11-20  18:43:00                6.324                  0.376
# 1059  2010-11-20  18:49:00                6.210                  0.174
#
#       Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# ...
